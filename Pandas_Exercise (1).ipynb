# %% [markdown]
# # <center>Introduction to Pandas</center>
#
# ![](https://pandas.pydata.org/_static/pandas_logo.png)
#
#
# ## Installation
#
# Simply,
# ```
# pip install pandas
# ```
#
#
# ## Reading data from a CSV file
#
# You can read data from a CSV file using the ``read_csv`` function. By default, it assumes that the fields are comma-separated.

# %%
# import pandas
import pandas as pd

# %% [markdown]
# >The `imdb.csv` dataset contains Highest Rated IMDb "Top 1000" Titles.

# %%
# load imdb dataset as pandas dataframe
data=pd.read_csv("imdb_1000.csv")
data
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#      content_rating      genre  duration  \
# 0    content_rating      Crime       142
# 1    content_rating      Crime       175
# 2    content_rating      Crime       200
# ...

# %%
# show first 5 rows of imdb_df
data.head()
# Out:
#    star_rating                     title  content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption  content_rating   Crime       142
# 1          9.2             The Godfather  content_rating   Crime       175
# 2          9.1    The Godfather: Part II  content_rating   Crime       200
# 3          9.0           The Dark Knight  content_rating  Action       152
# 4          8.9              Pulp Fiction  content_rating   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# >The `bikes.csv` dataset contains information about the number of bicycles that used certain bicycle lanes in Montreal in the year 2012.

# %%
# load bikes dataset as pandas dataframe
bike_s=pd.read_csv(r"C:\Users\mandar patil\Desktop\bikesdata.csv")
bike_s
# Out:
#            Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0    01/01/2012      00:00                 16      35             51
# 1    02/01/2012      00:00                 43      83            153
# 2    03/01/2012      00:00                 58     135            248
# 3    04/01/2012      00:00                 61     144            318
# 4    05/01/2012      00:00                 95     197            330
# ..          ...        ...                ...     ...            ...
# 361  27/12/2012      00:00                  8      12              7
# 362  28/12/2012      00:00                  0      35              3
# 363  29/12/2012      00:00                  0      27              8
# 364  30/12/2012      00:00                  0       5              1
# 365  31/12/2012      00:00                  0       4              3
#
#      Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# ...

# %%
# show first 3 rows of bikes_df
bike_s[0:3]
# Out:
#          Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0  01/01/2012      00:00                 16      35             51
# 1  02/01/2012      00:00                 43      83            153
# 2  03/01/2012      00:00                 58     135            248
#
#    Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# 0             38      5.0    26       10                            0
# 1             68     11.0    53        6                            1
# 2            104      2.0    89        3                            2
#
#    Pont_Jacques_Cartier
# 0                  27.0
# 1                  21.0
# 2                  15.0

# %% [markdown]
# ## Selecting columns
#
# When you read a CSV, you get a kind of object called a DataFrame, which is made up of rows and columns. You get columns out of a DataFrame the same way you get elements out of a dictionary.

# %%
# list columns of imdb_df
data.keys()
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
# what are the datatypes of values in columns
data.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# list first 5 movie titles
data["title"][1:6]
# Out:
# 1             The Godfather
# 2    The Godfather: Part II
# 3           The Dark Knight
# 4              Pulp Fiction
# 5              12 Angry Men
# Name: title, dtype: object

# %%
# show only movie title and genre
data[["title","genre"]]
# Out:
#                                                title      genre
# 0                           The Shawshank Redemption      Crime
# 1                                      The Godfather      Crime
# 2                             The Godfather: Part II      Crime
# 3                                    The Dark Knight     Action
# 4                                       Pulp Fiction      Crime
# ..                                               ...        ...
# 974                                          Tootsie     Comedy
# 975                      Back to the Future Part III  Adventure
# 976  Master and Commander: The Far Side of the World     Action
# 977                                      Poltergeist     Horror
# 978                                      Wall Street      Crime
#
# [979 rows x 2 columns]

# %% [markdown]
# ## Understanding columns
#
# On the inside, the type of a column is ``pd.Series`` and pandas Series are internally numpy arrays. If you add ``.values`` to the end of any Series, you'll get its internal **numpy array**.

# %%
# show the type of duration column
import numpy as np
data["duration"].dtypes
# Out:
# dtype('int64')

# %%
# show duration values of movies as numpy arrays
s=np.array(data['duration'])
s
# Out:
# array([142, 175, 200, 152, 154,  96, 161, 201, 195, 139, 178, 148, 124,
#        142, 179, 169, 133, 207, 146, 121, 136, 130, 130, 106, 127, 116,
#        175, 118, 110,  87, 125, 112, 102, 107, 119,  87, 169, 115, 112,
#        109, 189, 110, 150, 165, 155, 137, 113, 165,  95, 151, 155, 153,
#        125, 130, 116,  89, 137, 117,  88, 165, 170,  89, 146,  99,  98,
#        116, 156, 122, 149, 134, 122, 136, 157, 123, 119, 137, 128, 120,
#        229, 107, 134, 103, 177, 129, 102, 216, 136,  93,  68, 189,  99,
#        108, 113, 181, 103, 138, 110, 129,  88, 160, 126,  91, 116, 125,
#        143,  93, 102, 132, 153, 183, 160, 120, 138, 140, 153, 170, 129,
#         81, 127, 131, 172, 115, 108, 107, 129, 156,  96,  91,  95, 162,
#        130,  86, 186, 151,  96, 170, 118, 161, 131, 126, 131, 129, 224,
#        180, 105, 117, 140, 119, 124, 130, 139, 107, 132, 117, 126, 122,
#        178, 238, 149, 172,  98, 116, 116, 123, 148, 123, 182,  92,  93,
# ...

# %% [markdown]
# ## Applying functions to columns
#
# Use `.apply` function to apply any function to each element of a column.

# %%
# convert all the movie titles to uppercase
data["title"]=data["title"].str.upper()
data["title"]
# Out:
# 0                             THE SHAWSHANK REDEMPTION
# 1                                        THE GODFATHER
# 2                               THE GODFATHER: PART II
# 3                                      THE DARK KNIGHT
# 4                                         PULP FICTION
#                             ...
# 974                                            TOOTSIE
# 975                        BACK TO THE FUTURE PART III
# 976    MASTER AND COMMANDER: THE FAR SIDE OF THE WORLD
# 977                                        POLTERGEIST
# 978                                        WALL STREET
# Name: title, Length: 979, dtype: object

# %% [markdown]
# ## Plotting a column
#
# Use ``.plot()`` function!

# %%
# plot the bikers travelling to Berri1 over the year
import matplotlib.pyplot as plt
plt.plot(bike_s['Berri1'])

# %%
# plot all the columns of bikes_df
bike_s.plot(subplots=True, layout=(3,4),figsize=(30,40))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018C74C12308>,
# ...
#       dtype=object)

# %% [markdown]
# ## Value counts
#
# Get count of unique values in a particular column/Series.

# %%
# what are the unique genre in imdb_df?
imdf_df=data['genre'].unique()
print(imdf_df)
# Out:
# ['Crime' 'Action' 'Drama' 'Western' 'Adventure' 'Biography' 'Comedy'
#  'Animation' 'Mystery' 'Horror' 'Film-Noir' 'Sci-Fi' 'History' 'Thriller'
#  'Family' 'Fantasy']

# %%
# plotting value counts of unique genres as a bar chart
data['genre'].value_counts().plot(kind='bar',title='Genres',figsize=(10,10))

# %%
# plotting value counts of unique genres as a pie chart
data['genre'].value_counts().plot(kind='pie',radius=1,title='genres',figsize=(20,30))

# %% [markdown]
# ## Index
#
# ### DATAFRAME = COLUMNS + INDEX + ND DATA
#
# ### SERIES = INDEX + 1-D DATA
#
# **Index** or (**row labels**) is one of the fundamental data structure of pandas. It can be thought of as an **immutable array** and an **ordered set**.
#
# > Every row is uniquely identified by its index value.

# %%
# show index of bikes_df
print(bike_s.index)
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
# get row for date 2012-01-01
bike_s.loc[0]
# Out:
# Date                           01/01/2012
# Unnamed: 1                          00:00
# Rachel / Papineau                      16
# Berri1                                 35
# Maisonneuve_2                          51
# Maisonneuve_1                          38
# Brébeuf                                 5
# Parc                                   26
# PierDup                                10
# CSC (Côte Sainte-Catherine)             0
# Pont_Jacques_Cartier                   27
# Name: 0, dtype: object

# %% [markdown]
# #### To get row by integer index:
#
# Use ``.iloc[]`` for purely integer-location based indexing for selection by position.

# %%
# show 11th row of imdb_df using iloc
data.iloc[10]
# Out:
# star_rating                                                     8.8
# title             THE LORD OF THE RINGS: THE FELLOWSHIP OF THE RING
# content_rating                                       content_rating
# genre                                                     Adventure
# duration                                                        178
# actors_list       [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# Name: 10, dtype: object

# %% [markdown]
# ## Selecting rows where column has a particular value

# %%
# select only those movies where genre is adventure
data[data['genre']=='Adventure']['title']
# Out:
# 7          THE LORD OF THE RINGS: THE RETURN OF THE KING
# 10     THE LORD OF THE RINGS: THE FELLOWSHIP OF THE RING
# 14                 THE LORD OF THE RINGS: THE TWO TOWERS
# 15                                          INTERSTELLAR
# 54                                    BACK TO THE FUTURE
#                              ...
# 936                                            TRUE GRIT
# 937                                            LABYRINTH
# 943                                      THE BUCKET LIST
# 953                                THE NEVERENDING STORY
# 975                          BACK TO THE FUTURE PART III
# Name: title, Length: 75, dtype: object

# %%
# which genre has highest number of movies with star rating above 8 and duration more than 130 minutes?
data[(data.star_rating>8.0) & (data.duration>130)]['genre'].max()
# Out:
# 'Western'

# %% [markdown]
# ## Adding a new column to DataFrame

# %%
# add a weekday column to bikes_df
bike_s['weekday']=pd.to_datetime(bike_s['Date']).dt.day_name()
bike_s
# Out:
#            Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0    01/01/2012      00:00                 16      35             51
# 1    02/01/2012      00:00                 43      83            153
# 2    03/01/2012      00:00                 58     135            248
# 3    04/01/2012      00:00                 61     144            318
# 4    05/01/2012      00:00                 95     197            330
# ..          ...        ...                ...     ...            ...
# 361  27/12/2012      00:00                  8      12              7
# 362  28/12/2012      00:00                  0      35              3
# 363  29/12/2012      00:00                  0      27              8
# 364  30/12/2012      00:00                  0       5              1
# 365  31/12/2012      00:00                  0       4              3
#
#      Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# ...

# %% [markdown]
# ## Deleting an existing column from DataFrame

# %%
# remove column 'Unnamed: 1' from bikes_df
bike_s.drop('Unnamed: 1',inplace=True,axis=1)
bike_s
# Out:
#            Date  Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  \
# 0    01/01/2012                 16      35             51             38
# 1    02/01/2012                 43      83            153             68
# 2    03/01/2012                 58     135            248            104
# 3    04/01/2012                 61     144            318            116
# 4    05/01/2012                 95     197            330            124
# ..          ...                ...     ...            ...            ...
# 361  27/12/2012                  8      12              7              4
# 362  28/12/2012                  0      35              3             38
# 363  29/12/2012                  0      27              8             42
# 364  30/12/2012                  0       5              1              5
# 365  31/12/2012                  0       4              3              8
#
#      Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# ...

# %% [markdown]
# ## Deleting a row in DataFrame

# %%
# remove row no. 1 from bikes_df
bike_s.drop(1,inplace=True,axis=0)
bike_s
# Out:
#            Date  Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  \
# 0    01/01/2012                 16      35             51             38
# 2    03/01/2012                 58     135            248            104
# 3    04/01/2012                 61     144            318            116
# 4    05/01/2012                 95     197            330            124
# 5    06/01/2012                 75     146            244             98
# ..          ...                ...     ...            ...            ...
# 361  27/12/2012                  8      12              7              4
# 362  28/12/2012                  0      35              3             38
# 363  29/12/2012                  0      27              8             42
# 364  30/12/2012                  0       5              1              5
# 365  31/12/2012                  0       4              3              8
#
#      Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# ...

# %% [markdown]
# ## Group By
#
# Any groupby operation involves one of the following operations on the original object. They are −
#
# - Splitting the Object
#
# - Applying a function
#
# - Combining the results
#
# In many situations, we split the data into sets and we apply some functionality on each subset. In the apply functionality, we can perform the following operations −
#
# - **Aggregation** − computing a summary statistic
#
# - **Transformation** − perform some group-specific operation
#
# - **Filtration** − discarding the data with some condition

# %%
# group imdb_df by movie genres
data.groupby('genre')

# %%
# get crime movies group
x=data.groupby(data['genre']).get_group('Crime')
x
# Out:
#      star_rating                     title  content_rating  genre  duration  \
# 0            9.3  THE SHAWSHANK REDEMPTION  content_rating  Crime       142
# 1            9.2             THE GODFATHER  content_rating  Crime       175
# 2            9.1    THE GODFATHER: PART II  content_rating  Crime       200
# 4            8.9              PULP FICTION  content_rating  Crime       154
# 21           8.7               CITY OF GOD  content_rating  Crime       130
# ..           ...                       ...             ...    ...       ...
# 927          7.5                     BRICK               R  Crime       110
# 931          7.4              MEAN STREETS               R  Crime       112
# 950          7.4                     BOUND               R  Crime       108
# 969          7.4       LAW ABIDING CITIZEN               R  Crime       109
# 978          7.4               WALL STREET               R  Crime       126
#
#                                            actors_list
# ...

# %%
# get mean of movie durations for each group
x=data.groupby(['genre']).mean()
x
# Out:
#            star_rating    duration
# genre
# Action        7.884559  126.485294
# Adventure     7.933333  134.840000
# Animation     7.914516   96.596774
# Biography     7.862338  131.844156
# Comedy        7.822436  107.602564
# Crime         7.916935  122.298387
# Drama         7.902518  126.539568
# Family        7.850000  107.500000
# Fantasy       7.700000  112.000000
# Film-Noir     8.033333   97.333333
# History       8.000000   66.000000
# Horror        7.806897  102.517241
# Mystery       7.975000  115.625000
# Sci-Fi        7.920000  109.000000
# Thriller      7.680000  114.200000
# Western       8.255556  136.666667

# %%
# change duration of all movies in a particular genre to mean duration of the group
my_crime=data.groupby('genre').get_group('Crime')
my_crime['duration']=my_crime['duration'].mean()
my_crime[['title','duration']]
# Out:
# C:\Users\mandar patil\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                         title    duration
# 0    THE SHAWSHANK REDEMPTION  122.298387
# 1               THE GODFATHER  122.298387
# 2      THE GODFATHER: PART II  122.298387
# 4                PULP FICTION  122.298387
# 21                CITY OF GOD  122.298387
# ..                        ...         ...
# 927                     BRICK  122.298387
# 931              MEAN STREETS  122.298387
# 950                     BOUND  122.298387
# 969       LAW ABIDING CITIZEN  122.298387
# 978               WALL STREET  122.298387
#
# ...

# %%
# drop groups/genres that do not have average movie duration greater than 120.
data.groupby('genre').filter(lambda a:a['duration'].mean()>float(120))
# Out:
#      star_rating                                            title  \
# 0            9.3                         THE SHAWSHANK REDEMPTION
# 1            9.2                                    THE GODFATHER
# 2            9.1                           THE GODFATHER: PART II
# 3            9.0                                  THE DARK KNIGHT
# 4            8.9                                     PULP FICTION
# ..           ...                                              ...
# 972          7.4                                   BLUE VALENTINE
# 973          7.4                            THE CIDER HOUSE RULES
# 975          7.4                      BACK TO THE FUTURE PART III
# 976          7.4  MASTER AND COMMANDER: THE FAR SIDE OF THE WORLD
# 978          7.4                                      WALL STREET
#
#      content_rating      genre  duration  \
# 0    content_rating      Crime       142
# 1    content_rating      Crime       175
# 2    content_rating      Crime       200
# ...

# %%
# group weekday wise bikers count
x=bike_s.groupby('weekday').sum()

# %%
# get weekday wise biker count
x
# Out:
#            Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# weekday
# Friday                149402  155651         188838         106005  10019.0
# Monday                134966  140206         173675          96247  15976.0
# Saturday              130158  123719         132358          77071  10171.0
# Sunday                122230  113428         122742          67324  14098.0
# Thursday              147325  158044         190903         109796  16227.0
# Tuesday               128109  132563         162262          89861  10644.0
# Wednesday             141436  156540         190065         106485  14935.0
#
#              Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# weekday
# Friday      99924    47731                        63381               66798.0
# Monday      95962    42152                        61397               68785.0
# Saturday    66223    56076                        44808               54014.0
# ...

# %%
# plot weekday wise biker count for 'Berri1'
plt.plot(x['Berri1'],color='red')

# %% [markdown]
# ![](https://memegenerator.net/img/instances/500x/73988569/pythonpandas-is-easy-import-and-go.jpg)
